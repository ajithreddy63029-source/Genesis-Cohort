-- %%
-- -- creating customers table and inserting values
DROP TABLE IF EXISTS Customers1;
CREATE TABLE Customers1 (
    CustomerID INT,
    CustomerName STRING,
    City STRING,
    AccountType STRING,
    Balance INT,
    LoanAmount INT
);
INSERT INTO Customers1 VALUES
(101,'John','Dallas','Savings',5000,10000),
(102,'Mary','Austin','Current',2500,5000),
(103,'David','Dallas','Savings',8000,0),
(104,'Emma','Houston','Savings',1500,3000),
(105,'Alex','Austin','Current',7000,12000),
(106,'Sophia','Dallas','Savings',5000,8000);
select * from Customers1;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- ...

-- %%
--Q1 display the customername,city,balance and loanamount
SELECT CustomerName, City, Balance, LoanAmount
FROM Customers1;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>CustomerName</th><th>City</th><th>Balance</th><th>LoanAmount</th></tr></thead><tbody><tr><td>John</td><td>Dallas</td><td>5000</td><td>10000</td></tr><tr><td>Mary</td><td>Austin</td><td>2500</td><td>5000</td></tr><tr><td>David</td><td>Dallas</td><td>8000</td><td>0</td></tr><tr><td>Emma</td><td>Houston</td><td>1500</td><td>3000</td></tr><tr><td>Alex</td><td>Austin</td><td>7000</td><td>12000</td></tr><tr><td>Sophia</td><td>Dallas</td><td>5000</td><td>8000</td></tr></tbody></table></div>

-- %%
--Q2 unique cities
SELECT DISTINCT City 
FROM Customers1;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>City</th></tr></thead><tbody><tr><td>Dallas</td></tr><tr><td>Austin</td></tr><tr><td>Houston</td></tr></tbody></table></div>

-- %%
--Q3 sort customers by  loanamount in descending order and limit to top 5
SELECT DISTINCT City 
FROM Customers1;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>City</th></tr></thead><tbody><tr><td>Dallas</td></tr><tr><td>Austin</td></tr><tr><td>Houston</td></tr></tbody></table></div>

-- %%
--Q4 show only the top 5 customers by loanamount
SELECT *
FROM Customers1
ORDER BY LoanAmount DESC;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- ...

-- %%
--Q5 find the top 5 customers by loanamount
SELECT * FROM Customers1
ORDER BY LoanAmount DESC
LIMIT 5;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- ...

-- %%
--Q6 find the total number of customers
SELECT COUNT(*)As Total_Customers
FROM Customers1;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Total_Customers</th></tr></thead><tbody><tr><td>6</td></tr></tbody></table></div>

-- %%
--Q7 find the total loan amount
SELECT SUM(LoanAmount) AS Total_Loan_Amount
FROM Customers1;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Total_Loan_Amount</th></tr></thead><tbody><tr><td>38000</td></tr></tbody></table></div>

-- %%
--Q8 find the minimum balance
SELECT MIN(Balance) AS Minimum_Balance
FROM Customers1;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Minimum_Balance</th></tr></thead><tbody><tr><td>1500</td></tr></tbody></table></div>

-- %%
--Q9 find the maximum balance
SELECT MAX(Balance) AS Maxmimum_Balance
FROM Customers1;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Maxmimum_Balance</th></tr></thead><tbody><tr><td>8000</td></tr></tbody></table></div>

-- %%
--Q10 find the average balance
SELECT AVG(Balance) AS Average_Balance
FROM Customers1;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Average_Balance</th></tr></thead><tbody><tr><td>4833.333333333333</td></tr></tbody></table></div>
